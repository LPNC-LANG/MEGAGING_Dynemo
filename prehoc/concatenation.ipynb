# %%
from glob import glob
import os
from collections import defaultdict

BASE_DIR = "/run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING"
files = sorted(glob(f"{BASE_DIR}/Processed/osl_processing/Mot_Generation/*/*_raw.fif"))

# Associate each subject to its trials in a dict
subject_list = []
for file_ in files: # Extract subject names of each file
    subject_name = os.path.dirname(file_).split('/')[-1][-6:]
    subject_list.append(subject_name)

subject_files = defaultdict(list)
for file_, subject_name in zip(files, subject_list):
    subject_files[subject_name].append(file_)

# %%
import mne

os.makedirs(f"{BASE_DIR}/Processed/osl_processing/Mot_Generation/concatenated_data", exist_ok=True)
concatenated_trials = {}

for subject, files in subject_files.items():
    print(f"Concatenating trials for subject {subject} ...")
    print(f"{len(files)} trials found")
    
    new_fif = mne.io.read_raw_fif(files[0], verbose=False)
    for file_ in files[1:]:
        next_fif = mne.io.read_raw_fif(file_, verbose=False)
        new_fif = mne.concatenate_raws([new_fif, next_fif], on_mismatch='ignore')

    # Save the concatenated file
    new_fif.save(f"{BASE_DIR}/Processed/osl_processing/Mot_Generation/concatenated_data/{subject}_concatenated_raw.fif", overwrite=True)
    
    concatenated_trials[subject] = new_fif
    print(f"Successfully concatenated trials for subject {subject}\n")
# Out:
# Concatenating trials for subject bm_014 ...
# 80 trials found
# Writing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/bm_014_concatenated_raw.fif
# Closing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/bm_014_concatenated_raw.fif
# [done]
# Successfully concatenated trials for subject bm_014
#
# Concatenating trials for subject ca_001 ...
# 80 trials found
# Writing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/ca_001_concatenated_raw.fif
# Closing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/ca_001_concatenated_raw.fif
# [done]
# Successfully concatenated trials for subject ca_001
#
# Concatenating trials for subject ca_019 ...
# 80 trials found
# Writing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/ca_019_concatenated_raw.fif
# Closing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/ca_019_concatenated_raw.fif
# [done]
# Successfully concatenated trials for subject ca_019
#
# Concatenating trials for subject cc_007 ...
# 80 trials found
# Writing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/cc_007_concatenated_raw.fif
# Closing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/cc_007_concatenated_raw.fif
# [done]
# Successfully concatenated trials for subject cc_007
#
# Concatenating trials for subject cm_013 ...
# 80 trials found
# Writing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/cm_013_concatenated_raw.fif
# Closing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/cm_013_concatenated_raw.fif
# [done]
# Successfully concatenated trials for subject cm_013
#
# Concatenating trials for subject co_006 ...
# 80 trials found
# Writing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/co_006_concatenated_raw.fif
# Closing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/co_006_concatenated_raw.fif
# [done]
# Successfully concatenated trials for subject co_006
#
# Concatenating trials for subject dm_022 ...
# 80 trials found
# Writing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/dm_022_concatenated_raw.fif
# Closing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/dm_022_concatenated_raw.fif
# [done]
# Successfully concatenated trials for subject dm_022
#
# Concatenating trials for subject ds_021 ...
# 80 trials found
# Writing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/ds_021_concatenated_raw.fif
# Closing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/ds_021_concatenated_raw.fif
# [done]
# Successfully concatenated trials for subject ds_021
#
# Concatenating trials for subject el_018 ...
# 80 trials found
# Writing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/el_018_concatenated_raw.fif
# Closing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/el_018_concatenated_raw.fif
# [done]
# Successfully concatenated trials for subject el_018
#
# Concatenating trials for subject gb_020 ...
# 79 trials found
# Writing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/gb_020_concatenated_raw.fif
# Closing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/gb_020_concatenated_raw.fif
# [done]
# Successfully concatenated trials for subject gb_020
#
# Concatenating trials for subject gh_017 ...
# 80 trials found
# Writing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/gh_017_concatenated_raw.fif
# Closing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/gh_017_concatenated_raw.fif
# [done]
# Successfully concatenated trials for subject gh_017
#
# Concatenating trials for subject gp_011 ...
# 80 trials found
# Writing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/gp_011_concatenated_raw.fif
# Closing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/gp_011_concatenated_raw.fif
# [done]
# Successfully concatenated trials for subject gp_011
#
# Concatenating trials for subject gv_005 ...
# 80 trials found
# Writing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/gv_005_concatenated_raw.fif
# Closing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/gv_005_concatenated_raw.fif
# [done]
# Successfully concatenated trials for subject gv_005
#
# Concatenating trials for subject lf_012 ...
# 63 trials found
# Writing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/lf_012_concatenated_raw.fif
# Closing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/lf_012_concatenated_raw.fif
# [done]
# Successfully concatenated trials for subject lf_012
#
# Concatenating trials for subject lr_008 ...
# 80 trials found
# Writing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/lr_008_concatenated_raw.fif
# Closing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/lr_008_concatenated_raw.fif
# [done]
# Successfully concatenated trials for subject lr_008
#
# Concatenating trials for subject mp_004 ...
# 80 trials found
# Writing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/mp_004_concatenated_raw.fif
# Closing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/mp_004_concatenated_raw.fif
# [done]
# Successfully concatenated trials for subject mp_004
#
# Concatenating trials for subject pe_009 ...
# 80 trials found
# Writing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/pe_009_concatenated_raw.fif
# Closing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/pe_009_concatenated_raw.fif
# [done]
# Successfully concatenated trials for subject pe_009
#
# Concatenating trials for subject pl_016 ...
# 80 trials found
# Writing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/pl_016_concatenated_raw.fif
# Closing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/pl_016_concatenated_raw.fif
# [done]
# Successfully concatenated trials for subject pl_016
#
# Concatenating trials for subject pr_015 ...
# 80 trials found
# Writing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/pr_015_concatenated_raw.fif
# Closing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/pr_015_concatenated_raw.fif
# [done]
# Successfully concatenated trials for subject pr_015
#
# Concatenating trials for subject ra_003 ...
# 80 trials found
# Writing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/ra_003_concatenated_raw.fif
# Closing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/ra_003_concatenated_raw.fif
# [done]
# Successfully concatenated trials for subject ra_003
#
# Concatenating trials for subject re_002 ...
# 60 trials found
# Writing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/re_002_concatenated_raw.fif
# Closing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/re_002_concatenated_raw.fif
# [done]
# Successfully concatenated trials for subject re_002
#
# Concatenating trials for subject sg_010 ...
# 80 trials found
# Writing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/sg_010_concatenated_raw.fif
# Closing /run/user/1001/gvfs/smb-share:server=sum-lpnc-nas.u-ga.fr,share=securevault/LPNC-SecureVault/MEGAGING/Processed/osl_processing/Mot_Generation/concatenated_data/sg_010_concatenated_raw.fif
# [done]
# Successfully concatenated trials for subject sg_010
